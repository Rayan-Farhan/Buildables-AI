# %% [markdown]
# # <center> **Notebook 1 Tasks**

# %% [markdown]
# ###  **Task 1: What is prompting?**
# Prompting is the act of giving instructions, questions, or examples to a generative AI tool to guide it in producing a desired response or output.

# %% [markdown]
# ###  **Task 2: In the following prompt, which part describes the primary task?**
# ##### **Prompt: “Explain how car batteries work using non-technical language that someone without any mechanical knowledge could understand and interpret.”**
# Explain how car batteries work

# %% [markdown]
# ### **Task 3: When you are using a gen AI tool to create a healthy three-course menu that requires a certain number of calories, which prompting element will ensure the menu is more practical?**
# Adding context or constraints specifically, stating the required number of calories will make the menu more practical.

# %% [markdown]
# ### **Task 4: Prompting with audio to receive a visual representation is called what?**
# Multimodal prompting

# %% [markdown]
# ### **Task 5: What does a human-in-the-loop approach to prompting emphasize?**
# It emphasizes having a person review and verify AI outputs to ensure accuracy and relevance. Basically putting a human to ensure that the requirements are being satisfied.

# %% [markdown]
# ### **Task 6: When the initial prompt "Create a dataset" is too broad, what should you do to refine it?**
# I would make the prompt more specific by providing additional details, context, or maybe constraints about the dataset like topic, dataset size, structure, and use.

# %% [markdown]
# # <center> **Notebook 2 Tasks**

# %% [markdown]
# ### **Task 1: To-Do List with the Help of AI**
#
# Write project update email
# Prepare slides for Friday meeting
# Research competitor products
# Schedule 1:1s with team
# Task for AI: Write project update email
#
# Prompt:
# "Draft a professional, friendly email updating my team on our project’s progress and next steps."
#
# Sample AI Output:
#
# Hi Team,
#
# Great work on our project! We’ve completed the design phase, passed initial system tests, and welcomed new team members.
#
#
# Next Steps:
#
# Refine UI and start end-to-end testing by next Friday.
# Attend stakeholder review on [insert date, e.g., Sept 20].
# Update project documentation.
#
#
# Action Items:
#
# Review timeline in shared drive by EOD Wednesday.
#
# Contact Manager XYZ for task clarification.
#
#
# Keep up the momentum, and share any ideas! Thanks for your hard work.
#
#
# Best,
#
# Rayan Farhan
#
# Team Lead

# %% [markdown]
# ### **Task 2: Prompt then iterate**
#
# Email to Write:
# "Send a thank you email to a client after a successful project delivery."
# Prompt using framework:
# Persona: I am a project manager.
# Context: We just completed a project for a client.
# Task: Write a thank you email expressing appreciation and openness to future work.
# Specificity: Tone should be professional, warm, and concise.
#
# #### **Result:**
#
# Subject: Thank You for a Successful Project!
#
# Dear [Client’s Name],
#
# I hope this message finds you well. On behalf of the entire team, I want to express our heartfelt gratitude for the opportunity to work with you on [Project Name].
#
# We are thrilled to have successfully delivered the project and are delighted with the outcome.
#
# Your collaboration, clear communication, and valuable feedback were instrumental in making this project a success. It was a pleasure to work with you, and we truly appreciate your trust in us.
#
# We look forward to the possibility of collaborating again in the future. Please don’t hesitate to reach out if you have any further needs or ideas—we’d love to continue supporting your goals.
#
# Thank you once again for choosing us!
#
# Best regards,
#
# [Your Name]
#
# Project Manager
#
# [Your Company Name]
#
# #### **Result after iterating with prompt “Now, make it more casual and friendly”:**
#
# Subject: Big Thanks for [Project Name]!
#
# Hey [Client’s First Name],
#
# Just wanted to drop you a quick note to say a huge thank you for working with us on [Project Name]! We’re super excited about how it turned out and had a blast bringing it to life with you.
#
# Your awesome feedback and teamwork made all the difference. It was so great working with you, and we’d love to team up again down the road. If you’ve got more ideas or projects, just give us a shout!
#
# Thanks again for choosing us—you rock!
#
# Cheers,
#
# [Your First Name]
#
# Project Manager
#
# [Your Company Name]

# %% [markdown]
# ### **Task 3**:
#
# **Original text (LinkedIn post):** “Excited to announce our new product launch next week!”
#
# **Prompt for tone/style:** Rewrite this LinkedIn post to sound inspirational, like a TED speaker motivating professionals.
#
# **Result:** “Next week, we’re not just launching a product—we’re igniting possibility. This launch represents a vision: that innovation isn’t about technology alone, but about empowering people to think bigger, act bolder, and create meaningful change. Stay tuned. The best is yet to come.”
#
# **Prompt for tone/style:** Now make it formal and executive.
#
# **Result:** “We are pleased to share that next week we will officially launch our new product. This milestone reflects the dedication of our team, the trust of our partners, and our commitment to delivering meaningful solutions that create value. We look forward to introducing this innovation and to the opportunities it will unlock for our clients and stakeholders.”
#
# **Prompt for tone/style:** Now make it sound humorous and approachable.
#
# **Result:** “Big news: we’re launching a new product next week! 🚀 We can’t say too much yet (our legal team is already side-eyeing us), but let’s just say coffee has been our best friend, and sleep… not so much. Stay tuned—you won’t want to miss this one!”
#
# **Comparision:** Each version serves a different purpose. The inspirational tone works best if I would want to position yourself as visionary and motivate professionals. The formal executive tone is most effective when addressing clients, partners, or stakeholders who value credibility and professionalism. The humorous approachable tone is best for wider LinkedIn engagement, helping appear relatable and human.

# %% [markdown]
# ### **Task 4:**
#
# **Exercise 1: Icebreakers**
#
# Prompt:
# "Generate 3 creative icebreakers I can use to welcome a new teammate who loves basketball and photography. Make them fun, lighthearted, and conversation-starting."
#
# **Exercise 2: Product Launch**
#
# Prompt: "I’m launching a new mobile fitness app. Please:
#
# - Define a 6-month launch timeline with key milestones.
#
# - Suggest 3 creative pre-launch buzz ideas to build anticipation and attract early users."
#
# **Exercise 3: Global Audience Twist**
#
# Prompt:
# "Take the product launch plan for my new mobile fitness app and adjust the timeline and pre-launch buzz ideas so they are effective for a global audience across multiple cultures and regions."
#
# **Reflection Question Answer:**
#
# Generative AI can spark new ideas by acting like a creative partner as it helps us brainstorm fresh approaches, adapt messaging for different audiences, and uncover strategies we might not have considered on our own. In projects or the workplace, this means faster ideation, diverse perspectives, and more polished outputs we can refine into final solutions.

# %% [markdown]
# ### **Task 5:**
#
# **Exercise 1: Project Tracker**
#
# Prompt:
# "Create a project tracker table with the following columns: Task, Owner, Deadline, Status. Add a rule that no owner should have more than 2 active tasks at the same time."
#
# **Exercise 2: Event Schedule**
#
# Prompt:
# "I’m planning a 3-day conference. Generate a schedule with these columns: Day, Session Title, Speaker, and Time. Make sure no speaker has more than 1 session per day."
#
# **Exercise 3: Team Availability**
#
# Prompt:
# "Create a vacation tracker for 8 employees with columns: Employee, Vacation Start, Vacation End. Ensure that at least 5 employees remain available (not on vacation) at all times."
#
# **Reflection Question Answer:**
#
# AI can help organize recurring tasks by automating scheduling, assigning responsibilities, and tracking progress in real time. For example, it can generate weekly meeting agendas, remind team members of upcoming deadlines, or create resource calendars that automatically adjust when availability changes. This reduces manual planning effort and ensures consistency across projects.

# %% [markdown]
# ### **Task 6:**
#
# **Transcript:**
#
# *Ayesha: Thanks for joining. I wanted us to finalize the dataset for our FYP. We need something healthcare-related, and I’ve reached out to a hospital through my uncle.*
#
# *Bilal: That’s good. But let’s also check Kaggle as a backup. If the hospital delays, we might lose time.*
#
# *Hamza: Agreed. I’ll take responsibility for exploring Kaggle datasets this week.*
#
# *Ayesha: Perfect. Once we confirm the dataset, we should define the baseline model. I’m thinking federated learning with differential privacy.*
#
# *Bilal: Sounds good, but we need to write the feasibility report alongside. Otherwise, we’ll be rushing before the deadline.*
#
# *Hamza: I can draft the first section of the report. Deadline is next Friday, right?*
#
# *Ayesha: Yes. And I’ll handle preparing the slides for our upcoming presentation.*
#
# *Bilal: Great. Let’s check in again midweek to track progress.*
#
#
#
# **Exercise 1: Minutes by Speaker**
#
# Prompt:
# "Summarize the meeting into minutes by speaker. Add 2–3 bullet points per speaker, and mark action items clearly."
#
# Output:
#
# Ayesha:
#
# - Shared update on contacting hospital for healthcare dataset.
#
# - Suggested federated learning with differential privacy as baseline model.
#
# - Action Item: Prepare presentation slides.
#
# Bilal:
#
# - Recommended Kaggle as backup dataset source.
#
# - Emphasized importance of starting feasibility report early.
#
# - Action Item: None explicitly assigned.
#
# Hamza:
#
# - Agreed to explore Kaggle datasets this week.
#
# - Volunteered to draft first section of feasibility report.
#
# - Action Items: Explore Kaggle datasets; Draft first report section by Friday.
#
#
# **Exercise 2: Action Items Only**
#
# Prompt:
# "Create meeting minutes that focus only on action items. Format each entry as: Action Item, Responsible Person, Deadline."
#
# Output:
#
# Explore Kaggle datasets — Responsible: Hamza — Deadline: This week.
#
# Draft first section of feasibility report — Responsible: Hamza — Deadline: Next Friday.
#
# Prepare presentation slides — Responsible: Ayesha — Deadline: Before presentation.
#
# **Exercise 3: Topic-Based Minutes**
#
# Prompt:
# "Group meeting minutes into sections based on topics discussed. For each section, summarize key decisions, and list assigned action items."
#
# Output:
#
# Dataset Selection
#
# Decision: Primary dataset from hospital (Ayesha’s contact); Kaggle as backup option.
#
# Action Item: Hamza to explore Kaggle datasets (This week).
#
# Baseline Model
#
# Decision: Federated learning with differential privacy chosen as starting model.
#
# Action Item: None assigned.
#
# Feasibility Report
#
# Decision: Start drafting early to avoid last-minute rush.
#
# Action Item: Hamza to draft first section (Deadline: Next Friday).
#
# Presentation Preparation
#
# Decision: Ayesha to prepare slides for upcoming presentation.
#
# Action Item: Ayesha to complete slides before presentation date.
#
# **Reflection Question Answer:**
#
# AI-generated meeting notes help improve follow-up and accountability by clearly assigning tasks, tracking deadlines, and ensuring important points are documented for all team members.

# %% [markdown]
# ### **Task 7:**
#
# **Article:**
#
# The Internet: Transforming the Way We Live, Work, and Connect
#
# The internet—often called simply “the net”—is one of the most influential inventions of the modern age. What began as a small research project in the late 20th century has grown into a vast, interconnected network that links billions of people, devices, and systems worldwide. Today, it is hard to imagine a single day without it.
#
# A Brief History
#
# The origins of the internet trace back to the 1960s, when ARPANET was developed by the U.S. Department of Defense as a way to share information across computers. By the 1990s, the World Wide Web and web browsers made the internet accessible to everyday users, opening the door to email, search engines, and e-commerce.
#
# The Internet in Daily Life
#
# From checking news updates to ordering food, the internet has woven itself into nearly every aspect of our routines. Students use it for learning, professionals rely on it for remote work, and families use it to stay connected across continents. Social media platforms, video calls, and instant messaging have replaced many traditional forms of communication.
#
# Business and Innovation
#
# The net is not only a communication tool—it is also a driver of global commerce. Companies use online platforms to market products, provide customer service, and sell directly to consumers. Entire industries such as e-commerce, digital marketing, and cloud computing have emerged thanks to the internet. Startups, in particular, thrive because the net lowers barriers to entry, enabling innovation at scale.
#
# Challenges and Concerns
#
# Despite its benefits, the internet comes with challenges. Cybersecurity threats, misinformation, and privacy concerns are ongoing issues. Governments and organizations must work together to create safer online spaces without restricting freedom of expression. Additionally, the digital divide—the gap between those with internet access and those without—remains a pressing concern, particularly in developing countries.
#
# The Future of the Net
#
# As technologies such as artificial intelligence, 5G, and the Internet of Things (IoT) evolve, the net will continue to expand in scope and impact. Smart homes, connected cars, and advanced healthcare systems are just the beginning. The challenge will be balancing innovation with responsibility, ensuring the internet remains a tool for progress and inclusivity.
#
# Conclusion
#
# The internet has reshaped human life in ways once thought impossible. It connects people, fuels economies, and opens doors to knowledge. While challenges remain, its role as a cornerstone of modern civilization is undeniable. The future promises even greater transformations—making the net one of humanity’s most powerful tools.

# %% [markdown]
# **Exercise 1: Outline Summary**
#
# **Prompt:**
# *"Summarize this document into a bulleted outline of no more than 10 points."*
#
# **Output:**
#
# * Origins in 1960s with ARPANET, expanded widely in 1990s with the World Wide Web.
# * Internet now central to daily life: news, shopping, learning, remote work, socializing.
# * Businesses use it for marketing, e-commerce, and innovation.
# * Entire new industries (cloud, digital marketing, startups) emerged.
# * Communication shifted to social media, messaging, video calls.
# * Key challenges: cybersecurity, misinformation, privacy, and digital divide.
# * Governments/organizations must balance safety with freedom.
# * Future trends: AI, 5G, IoT, connected devices, smart systems.
# * Opportunities and risks must be managed responsibly.
# * Internet is a cornerstone of modern civilization, reshaping human progress.
#
#
# **Exercise 2: Audience Summary (High School Student)**
#
# **Prompt:**
# *"Summarize this document as if explaining it to a high school student."*
#
# **Output:**
# The internet started as a government project in the 1960s and grew into what we use every day now. It helps us learn, chat with friends, shop, and even do school or work from home. Businesses use it to sell products and reach customers worldwide. But there are also problems—like hackers, fake news, and some people not having access. In the future, with faster internet and smart technology, the net will keep changing how we live.
#
#
# **Exercise 3: Comparative Summary**
#
# **Prompt:**
# *"Summarize this report in two versions: 1. Executive summary for leadership. 2. Simplified version for frontline employees."*
#
# **Output:**
#
# 1. **Executive Summary (Leadership)**
#
# * The internet has evolved from ARPANET to a global infrastructure driving commerce, innovation, and communication.
# * It enables industries such as e-commerce, cloud, and digital services while presenting challenges (cybersecurity, misinformation, privacy).
# * Strategic priorities include addressing the digital divide and adopting emerging technologies (AI, 5G, IoT) responsibly.
# * The internet remains a critical enabler of growth, competitiveness, and stakeholder engagement.
#
# 2. **Simplified Version (Frontline Employees)**
#
# * The internet connects people everywhere and helps businesses run.
# * It lets us share information, work online, and reach customers.
# * There are risks like hacking and fake news, so safe online practices matter.
# * With new tech like faster internet and smart devices, the internet will keep changing how we work.
#
#
# **Reflection Question Answer:**
#
# Tailoring summaries for different audiences improves understanding by meeting people where they are. Executives need high-level insights to make decisions quickly. Clients need clarity on benefits and risks without technical jargon. Students or employees need simple explanations that connect to their experience. By shaping the same information for each audience, communication becomes clearer, decisions are better informed, and engagement increases.

# %% [markdown]
# ### **Task 8: Article: *“How chatbots are changing the internet”* (Financial Times).**
#
# **Step 1: Broad Overview (1 paragraph)**
#
# AI chatbots are rapidly reshaping the way people interact with the internet, moving far beyond customer support to roles in teaching, translation, and coding. While their capabilities unlock new opportunities, they also raise serious concerns about misinformation, deepfake impersonation, child safety, and the erosion of trust online. Experts argue that regulation, accountability, and education are critical to ensuring these technologies are used responsibly and that human agency is preserved.
#
# **Step 2: Shorter Summary (3 bullet points)**
#
# * Chatbots are expanding into education, programming, and daily internet use.
# * Risks include misinformation, impersonation, and harmful psychological effects.
# * Regulators and educators are pushing for safeguards and AI literacy in schools.
#
# **Step 3: Single Sentence (Main Trend/Insight)**
#
# AI chatbots are transforming the internet, but their growth demands urgent regulation and public awareness to balance innovation with safety.

# %% [markdown]
# # <center> **Notebook 3 Tasks**

# %% [markdown]
# ### **Task 1: Reflection Questions**
#
# 1) How is prompt chaining similar to solving a jigsaw puzzle?
# Prompt chaining breaks a big problem into many small, connected pieces. Each prompt produces one piece. You then connect those pieces and the output of one becomes the input for the next, until the full picture emerges. Like a puzzle, small pieces are easier to place and verify than trying to assemble the whole at once.
#
# 2) What’s the main difference between iteration and chaining?
# Iteration = keep rewording or tweaking a single prompt to get a better single response.
# Chaining = run a sequence of targeted prompts where each builds on the previous output to accomplish a multi-step task.
#
# 3) Why might chaining be more effective than asking AI one big question?
# Because large, complex tasks contain multiple subproblems (search, filter, synthesize, validate). A single prompt can overload the model or produce unfocused output. Chaining reduces cognitive load per step, preserves structure, makes errors easier to catch, and gives you checkpoints to verify before proceeding.
#
# 4) How can the context window of an AI model affect your chaining strategy?
# Models can “remember” only so much. If your chain produces long outputs, you must either summarize intermediate outputs before passing them on, or store large outputs externally and pass links/keys, or chunk the chain so each step stays within the context window.

# %% [markdown]
# ### **Task 2:**
#
# **Exercise 1:**
#
# - Summarize all emails: You are my email assistant. Here are my emails from the past week: <<paste emails>>. Summarize them into 5–7 categories with bullet points under each.
#
# - Highlight urgent tasks: From the email summary, identify all urgent or time-sensitive tasks. Mark each with: (a) Task, (b) Sender, (c) Deadline.
#
# - Suggest solutions for the most critical issue: Pick the single most critical issue from the urgent tasks list. Suggest 3 possible solutions, with pros and cons for each.
#
#
# **Exercise 2:**
#
# - Generate an outline of your paper: I am writing a research paper on [topic]. Create a 5-part outline (Intro, Related Work, Methods, Results, Discussion). Keep each section to 2–3 bullet points.
#
# - Suggest three key studies you should cite: Based on this outline, list three key studies (with titles, authors, year, and 1-sentence relevance) that I should cite.
#
# - Draft a short introduction: Using the outline + suggested studies, draft a 150-word introduction that sets context, states the gap, and presents the paper’s contribution.
#
#
# **Exercise 3:**
#
# - Create a one-sentence pitch: Create a one-sentence pitch for a new mobile app that helps users [insert purpose, e.g., track fitness with AI coaching].
#
# - Expand into a short paragraph: Expand this pitch into a short paragraph (4–5 sentences) describing the target audience, problem solved, and value proposition.
#
# - Generate a three-slide pitch deck outline: Using the paragraph, create a 3-slide investor pitch deck outline with slide titles and 3 bullet points per slide.

# %% [markdown]
# ### **Task 3: COT**
#
# **1:** Allocating a university’s $100,000 budget for student services across three areas: mental health counseling, career development, and campus activities.
#
#
# **2:** Help me allocate a $100,000 student services budget across mental health counseling, career development, and campus activities. Explain your reasoning step-by-step.
#
# **3:** Help me allocate a $100,000 student services budget across mental health counseling, career development, and campus activities. At least 50% must go to mental health counseling due to rising demand. Assume we have 10,000 students, most of them undergraduates. Explain your reasoning step-by-step.

# %% [markdown]
# ### **Task 4: COT**
#
# **1:** Brainstorming features for a new productivity app for students.
#
# **2:** Propose three innovative features for a productivity app designed for college students. Evaluate each idea for ease of implementation, potential user adoption, and long-term impact.
#
# **3:** Propose three innovative features for a productivity app designed for college students. At least one feature should use AI (e.g., study assistant). Evaluate each for ease of implementation, potential adoption, and long-term impact, and recommend the most promising one.

# %% [markdown]
# ### **Task 4: Advanced Prompting Techniques**
#
# **Exercise 1:** Help me decide which project to finish first: a client website or an internal tool. Explain your reasoning step by step.
#
# **Exercise 2:** Suggest three ideas for our company retreat theme. Evaluate each for cost and fun.
#
# **Exercise 3:** Propose three ways to launch our new app. Evaluate each briefly, then pick the best one and give me a simple step-by-step plan.
#
# **Reflection Question:** CoT would help me break big problems into smaller steps, making decisions clearer and less overwhelming. ToT would help me see multiple options side by side, sparking creative ideas I might not have thought of. Together, they give both clarity and variety, which is useful for solving complex tasks and brainstorming at work.

# %% [markdown]
# ### **Task 5: Practice Prompt Chaining**
#
# **Exercise 1 (Build a Project Step-by-Step):**
#
# **1:** Outline a company wellness program.
#
# **2:** Expand the section on mental health support.
#
# **3:** Suggest one interactive workshop activity.
#
# **Exercise 2 (CoT for Clarity):**
#
# **1:** Allocate a $5,000 budget for a product launch event.
#
# **2:** Explain your reasoning step by step.
#
# **Exercise 3 (ToT for Creativity):**
#
# **1:** Suggest three branding ideas for a new coffee shop.
#
# **2:** Evaluate each for uniqueness and customer appeal.
#
# **Exercise 4 (Combine CoT and ToT):**
#
# **1:** Propose three employee engagement activities and evaluate them.
#
# **2:** Pick the best one and plan it step by step with reasoning.
#
# **Reflection Question:**
# Prompt chaining breaks down complex projects into **smaller linked steps**, making them easier to manage. It also helps teams **collaborate better**, since each step builds clearly on the last.

# %% [markdown]
# ### **Task 6: Using AI to Analyze Large Datasets**
#
# **Exercise 1:**
#
# **2:** Analyze my 80-page business strategy report. Summarize the main arguments in bullet points.
#
# **3:** Highlight any gaps in logic or missing evidence that weaken the analysis.

# %% [markdown]
# ### **Task 7: Drafting with AI to Beat Deadlines**
#
# **Exercise 1:**
#
# **2:** Draft a professional email inviting clients to a product demo. Include date, time, and purpose.
#
# **3:** Keep the tone polite and concise.

# %% [markdown]
# ### **Task 8: Brainstorming with AI for Fresh Ideas**
#
# **Exercise 1:**
#
# **2:** Suggest three themes for a marketing campaign and explain their appeal to young adults.
#
# **3:** Keep ideas trendy and engaging.

# %% [markdown]
# ### **Task 9: Practice Using AI as Your Thought Partner**
#
# **Exercise 1: Analyze a Document**
#
# **1:** Summarize this 20-page report in 5 bullet points, focusing on key findings.
#
# **2:** Critique the draft article for clarity and persuasiveness.
#
# **Exercise 2: Draft for a Deadline**
#
# **1:** Draft a 200-word project summary for a client meeting tomorrow.
#
# **2:** Write a professional email updating the team on project delays.
#
# **Exercise 3: Brainstorm Ideas**
#
# **1:** Propose three event ideas for a team retreat and explain their benefits.
#
# **2:** Suggest three creative product features for a new app and explain why they would engage users.
#
# **Exercise 4: Combine Analysis and Drafting**
#
# **1:** Analyze this report for key trends, then draft a 100-word summary for executives.
#
# **2:** Summarize the research article and draft three social media posts highlighting its findings.
#
# **Reflection Question:**
# Enlisting AI as a thought partner could help me save time on repetitive drafting, spark fresh perspectives for creativity, and support faster, evidence-based decision-making in the workplace.

# %% [markdown]
# ### **Task 10: Prompt Generation Strategies**
#
# **Exercise 1: Direct Generation**
#
# **1:** Generate a prompt to create a weekly fitness plan for beginners, including workout types, duration, and rest days.

# %% [markdown]
# **Exercise 2: Template Request**
#
# **1:** Create a template for a prompt to design a weekly content calendar for a marketing team, including post types, platforms, and publishing schedule.

# %% [markdown]
# **Exercise 3: Image-Based Prompt Generation**
#
# **1:** Generate a prompt to design a book cover inspired by the attached abstract artwork, incorporating its bold color palette and geometric shapes to reflect a modern, creative theme.

# %% [markdown]
# **Exercise 4: Text-Based Prompt Generation**
#
# **1:** Using the attached annual report, generate a single clear prompt that asks an AI to: summarize the top five findings in bullet points, identify three strategic risks, and recommend two follow-up analyses. Keep the generated prompt concise and specify output format (bullets + short recommendations).

# %% [markdown]
# **Exercise 5: Meta-Prompt Chaining**
#
# **1:** Generate a prompt to write a concise welcome letter for new hires that includes: role summary (2 sentences), first-day logistics (time, place, contact), and a one-line tone guideline (friendly, professional).
#
# **2:** Using the welcome-letter prompt, generate a follow-up prompt that creates a 30-day onboarding schedule with weekly goals, a 1-line success metric per week, and three recommended check-in questions for managers.

# %% [markdown]
# ### **Task 11: Prompt Refinement Strategies**
#
# **Exercise 1: Leveling Up**
#
# **1:** How can I improve this prompt for a school newsletter so it sounds more engaging and fun?
#
# *Original Prompt:* “Write a short newsletter update about next week’s science fair.”
#
# **Exercise 2: Remixing**
#
# **1:** Combine these two prompts for a company training session into one clear version.
#
# *Prompt A:* “Write an agenda for a training session on communication skills.”
#
# *Prompt B:* “Include interactive exercises and a focus on workplace collaboration.”
#
# **Exercise 3: Style Swap**
#
# **1:** Rewrite this prompt to make it sound more motivational and inspiring.
#
# *Original Prompt:* “Write a guide about daily exercise routines for employees.”

# %% [markdown]
# ### **Task 12: Practice Meta-Prompting**
#
# **Exercise 1: Direct Generation**
#
# **1:** “Generate a prompt to write a professional follow-up email after a job interview.”
#
#
# **Exercise 2: Template Request**
#
# **1:** “Create a template for a prompt to draft a weekly progress report for project managers.”
#
# **Exercise 3: Prompt Refinement**
#
# **1:** “How can I improve this prompt for a presentation outline to make it more detailed and engaging? \[Attach prompt]”
#
# **Exercise 4: Meta-Prompt Chaining**
#
# **1:** “Generate a prompt for drafting the introduction of a business proposal, then another for creating the budget section.”
#
# **Reflection Question:**
# Meta-prompting can help me craft clearer and more targeted prompts, which leads to better AI outputs. It saves time, reduces trial-and-error, and ensures that the final results match the specific tone, detail, and structure needed for my work.

# %% [markdown]
# ### **Task 13: Building AgentSim: A Simulation AI Agent**
#
# **Exercise 1:**
#
# **1 (Initial Prompt):**
# “Act as a manager conducting a performance review with me. Support discussions on strengths, areas for improvement, and career development opportunities. End the role-play when I say ‘PAUSE.’ Afterward, provide feedback on how I communicated and suggested next steps.”
#
# **2 (Refined Prompt after Testing):**
# “Act as AgentSim, a manager conducting my annual performance review. Before starting, provide context about the role and performance period. During the review, cover three conversation types: (a) highlight my strengths, (b) discuss specific areas for improvement with examples, and (c) explore career development opportunities. Keep the tone professional yet supportive. End the role-play when I say ‘PAUSE.’ Afterward, summarize key takeaways with (1) communication effectiveness, (2) self-awareness, and (3) actionable steps.”

# %% [markdown]
# ### **Task 14: Building AgentX**
#
# **1:** “Act as AgentX, a project management consultant. Review my project plan and provide feedback on its (1) timeline, (2) resource allocation, and (3) risk management strategy. Suggest improvements where needed.”
#
# **2 [Refined Prompt]:** “Act as AgentX, a senior project management consultant. Review my attached project plan in detail. Provide feedback in three categories:
#
# 1. **Timeline:** Is it realistic and does it account for dependencies?
# 2. **Resource Allocation:** Are resources balanced and sufficient across phases?
# 3. **Risk Management:** Are risks identified and mitigation strategies included?
#
# Give your feedback in three parts: (a) strengths, (b) weaknesses, and (c) specific, actionable recommendations for improvement. Keep the tone constructive and professional.”

# %% [markdown]
# ### **Task 15: Practice Building AgentX**
#
# **Exercise 1: Create AgentX for Feedback**
#
# **1:** A **pitch deck draft** for investors.
#
# **2:** “Act as AgentX, a venture capital expert. Review my pitch deck draft for clarity, persuasiveness, and financial soundness. Continue until I say ‘FINISH.’ Provide a summary of strengths, gaps, and recommendations.”
#
# **Exercise 2: Refine with Meta-Prompting**
#
# **1:** Weak Prompt: “Review my code and tell me if it’s good.”
#
# **2:** Meta-Prompt: “How can I improve this prompt to get detailed, expert-level code review feedback on performance, readability, and best practices?”
#
# **Exercise 3: Use Context for Feedback**
#
# **1:** A **marketing campaign draft** with social media posts.
#
# **2:** “Act as AgentX, a digital marketing consultant. Review my attached campaign draft for creativity, audience appeal, and engagement potential. Continue until I say ‘DONE.’ Summarize key improvements.”
#
# **Exercise 4: Iterate Feedback**
#
# **2:** “Review my revised blog draft after applying your earlier feedback. [revised draft]. Provide additional suggestions for flow, tone, and reader engagement.”
#
# **Reflection Question:**
# AgentX’s expert feedback could help me refine deliverables step by step, spot weaknesses I might miss, and prepare polished outputs for high-stakes situations like investor pitches, client presentations, or published articles.

# %% [markdown]
# ### **Task 16: Practice Building AI Agents**
#
# **Exercise 1: Skill Practice Agent**
#
# **1:** Skill: Negotiation for a freelance contract
#
# **2:** Prompt: “Act as a client negotiating a freelance web development contract. Challenge me on pricing and deadlines. End when I say ‘SOLD.’ Provide feedback on persuasiveness, professionalism, and negotiation tactics.”
#
# **Exercise 2: Feedback Agent**
#
# **1:** Work Output: Presentation slides for a strategy meeting
#
# **2:** Prompt: “Act as a corporate strategy consultant. Critique my presentation slides for clarity, impact, and executive appeal. End when I say ‘PUBLISH.’ Provide structured strengths, weaknesses, and recommendations.”
#
# **Exercise 3: Learning Agent**
#
# **1:** Skill: SQL basics
#
# **2:** Prompt: “Act as a SQL tutor. Teach me beginner SQL concepts like SELECT, JOIN, and WHERE with short lessons and practice quizzes. End each session when I say ‘LESSON OVER.’”
#
# **Exercise 4: Collaboration Agent**
#
# **1:** Project Task: Drafting a research proposal
#
# **2:** Prompt: “Act as a research collaborator. Help me draft a proposal outline including problem statement, objectives, and methodology. End when I say ‘COMPLETE.’ Provide suggestions to strengthen clarity and structure.”
#
# **Reflection Question:**
# AI agents can help me by simulating real-world practice such as negotiation, providing expert feedback on outputs, teaching new skills step by step, and collaborating on complex projects. This makes problem-solving faster, learning more interactive, and work outputs more polished.

# %% [markdown]
# ### **Task 17: Practice Building Your Prompt Library**
#
# **Exercise 1: Create a Communication Prompt**
#
# **1:** Task: Internal company announcement
#
# **2:** Prompts:
#
# * v1 (Formal): “Write an internal company announcement informing staff about updated remote work policies. Maintain a professional and concise tone, highlighting key policy changes and effective dates.”
# * v2 (Casual): “Write a friendly company announcement to staff about updated remote work policies. Use an approachable tone, add encouragement about flexibility, and make it easy to understand.”
#
#
# **Exercise 2: Create a Content Prompt**
#
# **1:** Task: Social media post about a new product feature
#
# **2:** Prompts:
#
# * v1 (Audience: Consumers): “Write a social media post announcing a new feature for our mobile app. Keep it fun, engaging, and benefit-focused for everyday users.”
# * v2 (Audience: Businesses): “Write a LinkedIn post announcing a new mobile app feature, focusing on productivity, ROI, and professional use cases for business teams.”
#
#
# **Exercise 3: Use Meta-Prompting**
#
# **1:** Task: Weekly progress report
#
# **2:** Meta-Prompt: “Generate a prompt for writing a weekly project progress report with a clear, professional tone, including sections for achievements, challenges, and next steps.”

# %% [markdown]
# **Exercise 4: Organize Your Library**

# %%
import pandas as pd
data = {
    "Category": ["Email", "Social Media", "Reporting", "Training", "Marketing"],
    "Prompt": [
        "Write a formal meeting invitation email to a client.",
        "Create a fun Twitter post to promote a weekend discount offer.",
        "Summarize monthly sales performance in 5 key points.",
        "Draft simple onboarding instructions for new employees.",
        "Generate a product description for an eco-friendly water bottle."
    ],
    "Tone": ["Professional", "Playful", "Concise", "Clear", "Persuasive"],
    "Audience": ["Clients", "General public", "Executives", "New hires", "Shoppers"],
    "Effectiveness": [
        "Builds credibility, ensures attendance.",
        "Boosts visibility, drives quick engagement.",
        "Provides clarity, helps fast decision-making.",
        "Reduces confusion, speeds up onboarding.",
        "Increases interest, highlights unique value."
    ]
}

df = pd.DataFrame(data)

df
# Out:
#        Category                                             Prompt  \
# 0         Email  Write a formal meeting invitation email to a c...
# 1  Social Media  Create a fun Twitter post to promote a weekend...
# 2     Reporting  Summarize monthly sales performance in 5 key p...
# 3      Training  Draft simple onboarding instructions for new e...
# 4     Marketing  Generate a product description for an eco-frie...
#
#            Tone        Audience                                  Effectiveness
# 0  Professional         Clients        Builds credibility, ensures attendance.
# 1       Playful  General public    Boosts visibility, drives quick engagement.
# 2       Concise      Executives  Provides clarity, helps fast decision-making.
# 3         Clear       New hires       Reduces confusion, speeds up onboarding.
# 4    Persuasive        Shoppers   Increases interest, highlights unique value.

# %% [markdown]
# **Reflection Question:**
# A prompt library can help streamline repetitive tasks by keeping ready-made, tested prompts for emails, reports, and content creation. It improves AI outputs by ensuring consistent tone and audience alignment while saving time on rewriting prompts for similar tasks.
